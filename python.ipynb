# %% [markdown]
# <a href="https://colab.research.google.com/github/SHASHI1922/FarmPhilo-AI/blob/main/python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = "the asgaurd in that there is scarlet witch"
b = a.lower()
print(a[2:4])
print (a.upper())
# Out:
# e
# THE ASGAURD IN THAT THERE IS SCARLET WITCH

# %%
c = a.swapcase()
d = a.title()
e = a. capitalize()
f = a.count(a)
g = a.find(a)
print(d)
print(e)
print(f)
print(g)
# Out:
# The Asgaurd In That There Is Scarlet Witch
# The asgaurd in that there is scarlet witch
# 1
# 0

# %%
a = "sdfghjkjhgfd"
b = a.isdigit()
c = a.isalpha()
d = a.isalnum()
print (b)
print (c)
print (d)
# Out:
# False
# True
# True

# %%
a = "the asgaurd in that there is scarlet witch"
b = "".join(i for i in a if i in "aeiou")
print (b)      #join all the all vowels
# Out:
# eaauiaeeiaei

# %%
a ="the asgaurd in that there is scarlet witch"
b = sorted (a, reverse=True)#sort all z - a in revrse
print (b)
# Out:
# ['w', 'u', 't', 't', 't', 't', 't', 't', 's', 's', 's', 'r', 'r', 'r', 'n', 'l', 'i', 'i', 'i', 'h', 'h', 'h', 'h', 'g', 'e', 'e', 'e', 'e', 'd', 'c', 'c', 'a', 'a', 'a', 'a', ' ', ' ', ' ', ' ', ' ', ' ', ' ']

# %%
a = input ("enter pass : ")
up =0
lc = 0
sp = 0
dig = 0
if len(a)>7:
  for i in a :
    if i.isupper():
      up = up+1
    elif i.islower():
      lc= lc+1
    elif i.isdigit():
      dig = dig +1
    else :
      sp = sp + 1
  if up>0 and lc>0 and sp > 0 and dig>0:
    print ("strong")
  else :
      print ("f")
else :
  print("more weak")
# Out:
# enter pass : dfghjkl\
# f

# %%
#DIGITAL TIME
import time
import sys
h=3
s=0
m=40
while True:
  sys.stdout.write("\r{:02d}:{:02d}:{:02d}".format(h,m,s))
  sys.stdout.flush()
  time.sleep(1)
  s=s+1
  if s==60:
    s=0
    m=m+1
  if m==60:
    m=0
    h=h+1
  if h==24:
    h=0
# Out:
# 03:40:05

# %%
from datetime import datetime
import pytz  #date and time package
a=pytz.timezone("Asia/Kolkata")
b=datetime.now(a)
print(b)
for i in pytz.all_timezones:
  print(i)

# %%
#comprehnsive
#a = [chr(i) for i in range(65,91)].   #using asci value
a = [chr(i) for i in range(65,91) if chr(i) not in "AEIOU"]     #not in vowel
print(a)

# %%
a = 6789
b = [int (i) for i in str(a)]
print (max(b))                      #only max

# %%
#
names = ["starck","gruce","wanda","vision","soooop"]
marks = [30,40,50,60,70,80]
pos =1
for i in range(5):
  if marks [i]>40:
    print ("{}.{} has scored {}%".format (pos,names [i],marks[i]))
    pos = pos+1

# %%
#
names = ["starck","gruce","wanda","vision","soooop"]
marks = [30,40,50],[60,70,80],[99,88,90],[99,89,56],[45,67,88]
for i in range (5):
  p = sum (marks [i])//3
  if p >80 :
    g = "s"
  elif p<40:
    g = "f"
  elif p>40 and p<60 :
    g = "b"
  else :
      g = "A"
  print ("{}.mr/ms {} has scored {}%-{} Grade ".format(i+1,names [i].title(),p,g))
# Out:
# 1.mr/ms Starck has scored 40%-A Grade
# 2.mr/ms Gruce has scored 70%-A Grade
# 3.mr/ms Wanda has scored 92%-s Grade
# 4.mr/ms Vision has scored 81%-s Grade
# 5.mr/ms Soooop has scored 66%-A Grade

# %%
#zip (merging)
names = ["starck","gruce","wanda","vision","soooop"]
age = [24,45,55,65,45]
res = list(zip(names, age ))
res1 = sorted(res)
pos =1
for i in res1:
  print ("Rank {}: {} age is {} yrs old".format(pos,i[1],i[0]))
  pos+=1
# Out:
# Rank 1: 45 age is gruce yrs old
# Rank 2: 45 age is soooop yrs old
# Rank 3: 24 age is starck yrs old
# Rank 4: 65 age is vision yrs old
# Rank 5: 55 age is wanda yrs old

# %%
a=int (input("enter no of taeam "))
teams = []
for i in range (a):
  t = input("enter team name : ")
  teams.append(t)
m=int (input("enter no of taeam "))

matches =[]
pos =1
for i in range (0,a-1):
  for j in range (i+1,a):
    for k in range (m):
      matches.append([teams[i],teams[j]])
for i in matches:
  print("match {} : {} vs {}".format(pos,i[0],i[1]))
  pos+=1
# Out:
# enter no of taeam 5
# enter team name : srh
# enter team name : rr
# enter team name : rcb
# enter team name : csk
# enter team name : kkr
# enter no of taeam 2
# match 1 : srh vs rr
# match 2 : srh vs rr
# match 3 : srh vs rcb
# match 4 : srh vs rcb
# match 5 : srh vs csk
# match 6 : srh vs csk
# match 7 : srh vs kkr
# match 8 : srh vs kkr
# match 9 : rr vs rcb
# match 10 : rr vs rcb
# match 11 : rr vs csk
# match 12 : rr vs csk
# match 13 : rr vs kkr
# match 14 : rr vs kkr
# match 15 : rcb vs csk
# match 16 : rcb vs csk
# match 17 : rcb vs kkr
# match 18 : rcb vs kkr
# match 19 : csk vs kkr
# match 20 : csk vs kkr

# %%
from random import shuffle
a=int (input("enter no of taeam "))
teams = []
for i in range (a):
  t = input("enter team name : ")
  teams.append(t)
m=int (input("enter no ofmet taeam "))

matches =[]
for i in range (0,a-1):
  for j in range (i+1,a):
    for k in range (m):
      matches.append([teams[i],teams[j]])
      shuffle(matches)
pos =1
for i in matches:
  print("match {} : {} vs {}".format(pos,i[0],i[1]))
  pos+=1
# Out:
# enter no of taeam 2
# enter team name : ds]
# enter team name : h
# enter no of taeam 2
# match 1 : ds] vs h
# match 2 : ds] vs h
